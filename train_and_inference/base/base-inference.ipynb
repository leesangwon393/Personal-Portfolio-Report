# %%
import pandas as pd
df = pd.read_csv('/kaggle/input/nasdaq100/NASDAQ100_metrics.csv')
df = df.set_index('Ticker', drop = False)
company = df.to_dict(orient='index')

# %%
news = ["""
‘Tesla raised the U.S. price of its most expensive Cybertruck model, the Cyberbeast, by $15,000 to $114,990, adding a "Luxe Package" that includes Supervised Full Self-Driving and free Supercharger access. Other Cybertruck models remain unchanged. Despite this, Tesla has offered discounts of about $10,000 on some inventory. Production capacity is cited at over 125,000 units annually with potential for 250,000 in 2025, though sales remain limited; a recall in March 2025 covered about 46,000 vehicles produced since November 2023.’,
“The U.S. National Highway Traffic Safety Administration (NHTSA) has opened an audit into Tesla’s delays in submitting crash reports involving advanced driver-assistance and self-driving systems. The probe covers potential reporting violations and data collection issues. Separately, NHTSA is investigating 2.4 million Tesla vehicles over Full Self-Driving collisions, 2.6 million vehicles over remote-move crashes, and is reviewing Tesla’s June 2024 self-driving robotaxi deployment in Austin, Texas.”,
“A Miami federal jury ordered Tesla to pay $243 million in damages over a 2019 Autopilot-related fatal crash, including $200 million in punitive damages and $43 million in compensatory damages. Tesla stated it will appeal and cited a pre-trial agreement that could cap its liability at $172 million. The case marks one of the largest trial verdicts against Tesla related to Autopilot technology.”,
“Tesla awarded CEO Elon Musk 96 million restricted shares valued at about \\$29 billion as part of a new compensation grant, requiring him to pay \\$23.34 per share to vest. This follows the Delaware court’s revocation of Musk’s 2018 pay package, currently under appeal. Tesla reported Q2 profit of \\$409 million, down from \\$1.39 billion a year earlier, with revenue also declining. An annual shareholder meeting is scheduled for November to comply with Texas law.”,
“U.S. labor unions and advocacy groups urged state financial officers overseeing public pension funds to oppose Tesla’s new \\$29 billion stock grant to CEO Elon Musk, which consists of 96 million restricted shares. The award follows the Delaware court’s 2023 voiding of Musk’s 2018 compensation package valued at up to \\$56 billion, currently under appeal. Tesla shareholders ratified the 2018 package and approved relocating the company’s legal home to Texas, but the case remains unresolved.”,
“Tesla evacuated part of its German plant after a fire in a battery pack processing building; there were no injuries or environmental damage reported. No additional financial details or production impact were disclosed.”,
“Tesla launched a six-seat Model Y variant in China at \\~\\$47,200, produced at its Shanghai factory. Production of this variant in the U.S. may be delayed until late next year or potentially not occur. Tesla plans a lower-cost Model Y variant later this year and is scaling its limited robotaxi service in Austin.”,
“Tesla launched a limited robotaxi service in Austin, Texas, deploying \\~10 self-driving vehicles with paying passengers at \\$4.20 per ride. The service requires front-seat safety monitors and operates under new Texas autonomous-vehicle permit rules effective September 1. No production, revenue, or broader deployment figures were disclosed.”,
“Tesla plans to expand its robotaxi service to the San Francisco Bay Area within one to two months, pending regulatory approvals. The company is also expanding the Austin service to a larger area. California requires multiple state permits for full autonomous robotaxi operations, with the CPUC granting initial approval.”,
“Tesla reported a 12% decline in revenue and a 16% drop in profit for the April-June quarter. The company began rolling out a paid robotaxi service in Austin, Texas, in June and plans to expand to other U.S. cities, targeting roughly half of the U.S. population by year-end, subject to regulatory approvals. Tesla faces the loss of the \\$7,500 EV tax credit and reduced revenue from selling regulatory credits. U.S. tariffs on China and Mexico are expected to cost the company hundreds of millions of dollars.”,
“Tesla has received over 600 orders in India since launching sales in mid-July. The company plans to ship 350 to 500 cars this year, with the first batch arriving from Shanghai in early September. Deliveries will be limited to Mumbai, Delhi, Pune, and Gurugram. The Model Y is priced at approximately $70,000.”
“In August, South Korean retail investors sold a net $657 million in Tesla shares, totaling $1.8 billion in the last four months. Despite this, Tesla remains the top foreign stock among Korean investors with $21.9 billion in holdings. The TSLL ETF also experienced significant outflows, losing $554 million.”,
“Tesla is advancing its robotaxi program, having initiated a test in Austin in June, with plans for widespread availability by year-end. The company is focusing on a cost-effective approach using cameras and AI. Analysts project Tesla will not achieve fully self-driving robotaxis until 2028, amid challenges including regulatory hurdles and community pushback.”,
“In August, Tesla's new vehicle registrations in Sweden fell to 210, an 84% decrease from over 1,000 a year prior. Competitors Volvo, Volkswagen, and Toyota reported strong growth with over 2,700, 2,600, and 2,200 registrations, respectively. Tesla's sales in Europe have been declining for seven consecutive months.”,
“Tesla's car registrations in several European markets fell significantly in August, with declines of 47.3% in France, over 84% in Sweden, and 42% in Denmark. However, registrations rose 21.3% in Norway and 28.7% in Portugal. In Spain, sales increased 161%, but BYD's sales surged over 400%. Tesla's market share in Western Europe dropped to 1.7% from 2.5% in"
"""]

# %%
# ticker = input('ticker: ')
# investor_style = input('investor_style: ')
ticker = "TSLA"
investor_style = "RISKY"
company_data = str(company[ticker])
# news = "\n".join(recent_news)

# %%
user_prompt = f"""Analyze all the provided data and generate a report tailored to the investor's profile.
    1. Investor Style: {investor_style}
    
    2. Company Under Review, Key Data from Corporate Filings:
    {company_data}
    
    3. Recent News (Last 10 Articles):
    {news}
"""

# %%
system_prompt = """You are an expert financial analyst. Your mission is to write a concise, objective investment report for a client based on their specific risk profile.

ANALYSIS INSTRUCTIONS: 
- Use BOTH the provided financial metrics ("Facts") and recent news headlines ("News"). 
- Always include the metrics listed under `core_metrics` in Facts. These are the most important indicators for the company/sector. 
- Each Key Highlight should integrate at least one financial fact and one news item together (not listed separately). 
- Do not hallucinate numbers that are not in Facts. 
- Adjust the focus and tone strictly based on the investor's style: 

If the style is SAFE (Conservative):
* Focus: Capital preservation and stable income. 
* Highlight: Balance sheet strength, liquidity, predictable returns. 
* Mention risks (regulatory, legal, earnings decline) first, then cautiously note positives. 
* Downplay speculative or uncertain news.

If the style is NEUTRAL (Moderate):
* Focus: A balance between growth and safety. 
* Highlight: Strategic trade-offs. Analyze how growth initiatives (from news) interact with financial stability (from facts). 
* Present risks and opportunities in equal measure. 

If the style is RISKY (Aggressive):
* Focus: High growth potential and maximum returns. 
* Highlight: Exciting, forward-looking growth story. Emphasize innovation, expansion, competitive advantages. 
* Frame risks as natural volatility on the path to high rewards. 
* Place financial facts in the context of supporting aggressive growth. 

OUTPUT REPORT TEMPLATE
Report for: A (investor_style) Investor
Company: (company_name)

1. Executive Summary:
   (Provide a brief, one-paragraph summary that aligns with the investor's style, integrating at least one key metric and one recent news item.)

2. Key Analysis & Highlights:
   (5–7 bullet points. Each bullet must combine a financial metric with a relevant news event, written from the perspective of the given investor style.)

3. Concluding Remark:
   (One or two sentences, neutrally summarizing the company’s current standing for this type of investor. 
   Do NOT provide direct financial advice or buy/sell recommendations.)

IMPORTANT:
- Keep the tone professional and concise. 
- Reports must be grounded in Facts and News only. 
- Different investor styles should produce clearly differentiated tone and emphasis.
"""

# %%
hf_token = "Put your own HF token here"
from huggingface_hub import login
# Login directly with your Token (remember not to share this Token publicly)
login(token=hf_token)

# %%
from transformers import LlamaForCausalLM, LlamaTokenizerFast
from peft import PeftModel
import torch

# 1. 모델 및 토크나이저 설정
base_model_path = "meta-llama/Meta-Llama-3-8B-Instruct"
num_gpus = torch.cuda.device_count()
max_memory = {i: "11GiB" for i in range(num_gpus)}

# 토크나이저 로드
tokenizer = LlamaTokenizerFast.from_pretrained(base_model_path, trust_remote_code=True)
tokenizer.pad_token = tokenizer.eos_token

# 2. 베이스 모델 로드 및 답변 생성
print("--- 1. Base Model (PEFT 적용 전) 로딩 및 답변 생성 ---")
base_model = LlamaForCausalLM.from_pretrained(
    base_model_path,
    torch_dtype=torch.bfloat16,
    trust_remote_code=True,
    device_map="balanced", # "auto" 대신 "balanced" 사용하여 균등 분배
    max_memory=max_memory
)
base_model.eval()
# Out:
# 2025-09-02 12:12:52.816630: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1756815173.157350     111 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1756815173.255309     111 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# tokenizer_config.json:   0%|          | 0.00/51.0k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/9.09M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/73.0 [00:00<?, ?B/s]
# ...

# %%
# 시스템과 사용자 역할을 구분하여 messages 리스트 생성
massage = [
    {"role": "system", "content": system_prompt},
    {"role": "user", "content": user_prompt}]
# 토크나이저 정의
tokens = tokenizer.apply_chat_template(massage,tokenize=True,padding=True,add_generation_prompt=True, return_tensors="pt").to("cuda:0")
input_ids_length = tokens.shape[1]

with torch.no_grad():
    res_base = base_model.generate(tokens, max_new_tokens=1024)
generated_tokens = res_base[0, input_ids_length:]


print("\n[베이스 모델 답변] ", tokenizer.decode(generated_tokens, skip_special_tokens=True))
# Out:
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# [베이스 모델 답변]  Report for: RISKY Investor
#
# Company: Tesla (TSLA)
#
# 1. Executive Summary:
# Tesla's aggressive growth strategy and innovative products have made it an attractive investment opportunity. Despite recent setbacks, the company's forward-looking growth story remains exciting. With a strong cash position and a growing presence in the electric vehicle market, Tesla is poised for high growth potential. However, investors should be aware of the regulatory and legal challenges the company faces, particularly in regards to its autonomous driving technology.
#
# 2. Key Analysis & Highlights:
# ...
